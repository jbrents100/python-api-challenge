# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# !pip install cartopy geoviews pyproj
# Out:
# Collecting cartopy
#   Obtaining dependency information for cartopy from https://files.pythonhosted.org/packages/bb/50/ab5495dcc22587179134cd37e6534212babeda78e86bda311c37c773f086/Cartopy-0.22.0-cp311-cp311-win_amd64.whl.metadata
#   Downloading Cartopy-0.22.0-cp311-cp311-win_amd64.whl.metadata (15 kB)
# Collecting geoviews
#   Obtaining dependency information for geoviews from https://files.pythonhosted.org/packages/7c/b1/c27b294bc3bfc06d7721082568f53d076918a039864afc656d6d237fe08b/geoviews-1.10.1-py2.py3-none-any.whl.metadata
#   Downloading geoviews-1.10.1-py2.py3-none-any.whl.metadata (11 kB)
# Collecting pyproj
#   Obtaining dependency information for pyproj from https://files.pythonhosted.org/packages/79/95/eb68113c5b5737c342bde1bab92705dabe69c16299c5a122616e50f1fbd6/pyproj-3.6.1-cp311-cp311-win_amd64.whl.metadata
#   Downloading pyproj-3.6.1-cp311-cp311-win_amd64.whl.metadata (31 kB)
# Requirement already satisfied: numpy>=1.21 in c:\users\jesse.brents\appdata\local\anaconda3\lib\site-packages (from cartopy) (1.24.3)
# Requirement already satisfied: matplotlib>=3.4 in c:\users\jesse.brents\appdata\local\anaconda3\lib\site-packages (from cartopy) (3.7.1)
# Collecting shapely>=1.7 (from cartopy)
#   Obtaining dependency information for shapely>=1.7 from https://files.pythonhosted.org/packages/9e/39/029c441d8af32ab423b229c4525ce5ce6707318155b59634811a4c56f5c4/shapely-2.0.2-cp311-cp311-win_amd64.whl.metadata
#   Downloading shapely-2.0.2-cp311-cp311-win_amd64.whl.metadata (7.2 kB)
# Requirement already satisfied: packaging>=20 in c:\users\jesse.brents\appdata\local\anaconda3\lib\site-packages (from cartopy) (23.0)
# Collecting pyshp>=2.1 (from cartopy)
#   Downloading pyshp-2.3.1-py2.py3-none-any.whl (46 kB)
#      ---------------------------------------- 0.0/46.5 kB ? eta -:--:--
#      ---------------------------------------- 46.5/46.5 kB 2.3 MB/s eta 0:00:00
# Requirement already satisfied: bokeh<3.3.0,>=3.1.0 in c:\users\jesse.brents\appdata\local\anaconda3\lib\site-packages (from geoviews) (3.2.1)
# Requirement already satisfied: holoviews>=1.16.0 in c:\users\jesse.brents\appdata\local\anaconda3\lib\site-packages (from geoviews) (1.17.0)
# Requirement already satisfied: param in c:\users\jesse.brents\appdata\local\anaconda3\lib\site-packages (from geoviews) (1.13.0)
# Requirement already satisfied: panel>=1.0.0 in c:\users\jesse.brents\appdata\local\anaconda3\lib\site-packages (from geoviews) (1.2.1)
# Requirement already satisfied: xyzservices in c:\users\jesse.brents\appdata\local\anaconda3\lib\site-packages (from geoviews) (2022.9.0)
# Requirement already satisfied: certifi in c:\users\jesse.brents\appdata\local\anaconda3\lib\site-packages (from pyproj) (2023.7.22)
# Requirement already satisfied: Jinja2>=2.9 in c:\users\jesse.brents\appdata\local\anaconda3\lib\site-packages (from bokeh<3.3.0,>=3.1.0->geoviews) (3.1.2)
# Requirement already satisfied: contourpy>=1 in c:\users\jesse.brents\appdata\local\anaconda3\lib\site-packages (from bokeh<3.3.0,>=3.1.0->geoviews) (1.0.5)
# Requirement already satisfied: pandas>=1.2 in c:\users\jesse.brents\appdata\local\anaconda3\lib\site-packages (from bokeh<3.3.0,>=3.1.0->geoviews) (1.5.3)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\jesse.brents\appdata\local\anaconda3\lib\site-packages (from bokeh<3.3.0,>=3.1.0->geoviews) (9.4.0)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\jesse.brents\appdata\local\anaconda3\lib\site-packages (from bokeh<3.3.0,>=3.1.0->geoviews) (6.0)
# Requirement already satisfied: tornado>=5.1 in c:\users\jesse.brents\appdata\local\anaconda3\lib\site-packages (from bokeh<3.3.0,>=3.1.0->geoviews) (6.3.2)
# Requirement already satisfied: pyviz-comms>=0.7.4 in c:\users\jesse.brents\appdata\local\anaconda3\lib\site-packages (from holoviews>=1.16.0->geoviews) (2.3.0)
# Requirement already satisfied: colorcet in c:\users\jesse.brents\appdata\local\anaconda3\lib\site-packages (from holoviews>=1.16.0->geoviews) (3.0.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\jesse.brents\appdata\local\anaconda3\lib\site-packages (from matplotlib>=3.4->cartopy) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\jesse.brents\appdata\local\anaconda3\lib\site-packages (from matplotlib>=3.4->cartopy) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\jesse.brents\appdata\local\anaconda3\lib\site-packages (from matplotlib>=3.4->cartopy) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\jesse.brents\appdata\local\anaconda3\lib\site-packages (from matplotlib>=3.4->cartopy) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\jesse.brents\appdata\local\anaconda3\lib\site-packages (from matplotlib>=3.4->cartopy) (2.8.2)
# Requirement already satisfied: markdown in c:\users\jesse.brents\appdata\local\anaconda3\lib\site-packages (from panel>=1.0.0->geoviews) (3.4.1)
# Requirement already satisfied: markdown-it-py in c:\users\jesse.brents\appdata\local\anaconda3\lib\site-packages (from panel>=1.0.0->geoviews) (2.2.0)
# Requirement already satisfied: linkify-it-py in c:\users\jesse.brents\appdata\local\anaconda3\lib\site-packages (from panel>=1.0.0->geoviews) (2.0.0)
# Requirement already satisfied: mdit-py-plugins in c:\users\jesse.brents\appdata\local\anaconda3\lib\site-packages (from panel>=1.0.0->geoviews) (0.3.0)
# Requirement already satisfied: requests in c:\users\jesse.brents\appdata\local\anaconda3\lib\site-packages (from panel>=1.0.0->geoviews) (2.31.0)
# Requirement already satisfied: tqdm>=4.48.0 in c:\users\jesse.brents\appdata\local\anaconda3\lib\site-packages (from panel>=1.0.0->geoviews) (4.65.0)
# Requirement already satisfied: bleach in c:\users\jesse.brents\appdata\local\anaconda3\lib\site-packages (from panel>=1.0.0->geoviews) (4.1.0)
# Requirement already satisfied: typing-extensions in c:\users\jesse.brents\appdata\local\anaconda3\lib\site-packages (from panel>=1.0.0->geoviews) (4.7.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\jesse.brents\appdata\local\anaconda3\lib\site-packages (from Jinja2>=2.9->bokeh<3.3.0,>=3.1.0->geoviews) (2.1.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jesse.brents\appdata\local\anaconda3\lib\site-packages (from pandas>=1.2->bokeh<3.3.0,>=3.1.0->geoviews) (2022.7)
# Requirement already satisfied: six>=1.5 in c:\users\jesse.brents\appdata\local\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.4->cartopy) (1.16.0)
# Requirement already satisfied: colorama in c:\users\jesse.brents\appdata\local\anaconda3\lib\site-packages (from tqdm>=4.48.0->panel>=1.0.0->geoviews) (0.4.6)
# Requirement already satisfied: webencodings in c:\users\jesse.brents\appdata\local\anaconda3\lib\site-packages (from bleach->panel>=1.0.0->geoviews) (0.5.1)
# Requirement already satisfied: pyct>=0.4.4 in c:\users\jesse.brents\appdata\local\anaconda3\lib\site-packages (from colorcet->holoviews>=1.16.0->geoviews) (0.5.0)
# Requirement already satisfied: uc-micro-py in c:\users\jesse.brents\appdata\local\anaconda3\lib\site-packages (from linkify-it-py->panel>=1.0.0->geoviews) (1.0.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\jesse.brents\appdata\local\anaconda3\lib\site-packages (from markdown-it-py->panel>=1.0.0->geoviews) (0.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\jesse.brents\appdata\local\anaconda3\lib\site-packages (from requests->panel>=1.0.0->geoviews) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jesse.brents\appdata\local\anaconda3\lib\site-packages (from requests->panel>=1.0.0->geoviews) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jesse.brents\appdata\local\anaconda3\lib\site-packages (from requests->panel>=1.0.0->geoviews) (1.26.16)
# Downloading Cartopy-0.22.0-cp311-cp311-win_amd64.whl (11.2 MB)
#    ---------------------------------------- 0.0/11.2 MB ? eta -:--:--
#    ---------------------------------------- 0.1/11.2 MB 3.8 MB/s eta 0:00:03
#     --------------------------------------- 0.3/11.2 MB 4.2 MB/s eta 0:00:03
#    - -------------------------------------- 0.5/11.2 MB 4.1 MB/s eta 0:00:03
#    -- ------------------------------------- 0.7/11.2 MB 4.2 MB/s eta 0:00:03
#    ----- ---------------------------------- 1.4/11.2 MB 6.9 MB/s eta 0:00:02
#    ------- -------------------------------- 2.0/11.2 MB 7.8 MB/s eta 0:00:02
#    ------- -------------------------------- 2.0/11.2 MB 7.4 MB/s eta 0:00:02
#    ------- -------------------------------- 2.0/11.2 MB 7.4 MB/s eta 0:00:02
#    ----------- ---------------------------- 3.3/11.2 MB 8.8 MB/s eta 0:00:01
#    ------------- -------------------------- 3.8/11.2 MB 8.9 MB/s eta 0:00:01
#    --------------- ------------------------ 4.4/11.2 MB 9.5 MB/s eta 0:00:01
#    ------------------ --------------------- 5.1/11.2 MB 9.8 MB/s eta 0:00:01
#    -------------------- ------------------- 5.8/11.2 MB 10.3 MB/s eta 0:00:01
#    ----------------------- ---------------- 6.5/11.2 MB 10.6 MB/s eta 0:00:01
#    ------------------------ --------------- 6.8/11.2 MB 10.7 MB/s eta 0:00:01
#    -------------------------- ------------- 7.4/11.2 MB 11.0 MB/s eta 0:00:01
#    --------------------------- ------------ 7.8/11.2 MB 10.3 MB/s eta 0:00:01
#    ------------------------------ --------- 8.5/11.2 MB 10.6 MB/s eta 0:00:01
#    ------------------------------- -------- 8.8/11.2 MB 10.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 9.5/11.2 MB 10.8 MB/s eta 0:00:01
#    ------------------------------------ --- 10.1/11.2 MB 10.9 MB/s eta 0:00:01
#    -------------------------------------- - 10.8/11.2 MB 12.4 MB/s eta 0:00:01
#    ---------------------------------------  11.1/11.2 MB 12.1 MB/s eta 0:00:01
#    ---------------------------------------- 11.2/11.2 MB 11.7 MB/s eta 0:00:00
# Downloading geoviews-1.10.1-py2.py3-none-any.whl (509 kB)
#    ---------------------------------------- 0.0/509.8 kB ? eta -:--:--
#    --------------------------------------- 509.8/509.8 kB 16.1 MB/s eta 0:00:00
# Downloading pyproj-3.6.1-cp311-cp311-win_amd64.whl (6.1 MB)
#    ---------------------------------------- 0.0/6.1 MB ? eta -:--:--
#    --- ------------------------------------ 0.6/6.1 MB 12.4 MB/s eta 0:00:01
#    --------- ------------------------------ 1.4/6.1 MB 15.2 MB/s eta 0:00:01
#    --------- ------------------------------ 1.5/6.1 MB 10.7 MB/s eta 0:00:01
#    ----------- ---------------------------- 1.7/6.1 MB 11.1 MB/s eta 0:00:01
#    ------------ --------------------------- 1.9/6.1 MB 8.2 MB/s eta 0:00:01
#    -------------------- ------------------- 3.1/6.1 MB 10.9 MB/s eta 0:00:01
#    ----------------------- ---------------- 3.6/6.1 MB 10.8 MB/s eta 0:00:01
#    ------------------------- -------------- 3.9/6.1 MB 10.3 MB/s eta 0:00:01
#    ----------------------------- ---------- 4.5/6.1 MB 10.5 MB/s eta 0:00:01
#    -------------------------------- ------- 4.9/6.1 MB 10.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 5.5/6.1 MB 10.3 MB/s eta 0:00:01
#    ------------------------------------- -- 5.7/6.1 MB 10.4 MB/s eta 0:00:01
#    ---------------------------------------  6.1/6.1 MB 10.0 MB/s eta 0:00:01
#    ---------------------------------------- 6.1/6.1 MB 9.3 MB/s eta 0:00:00
# Downloading shapely-2.0.2-cp311-cp311-win_amd64.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    --------- ------------------------------ 0.3/1.4 MB 9.9 MB/s eta 0:00:01
#    -------------- ------------------------- 0.5/1.4 MB 5.6 MB/s eta 0:00:01
#    ------------------------- -------------- 0.9/1.4 MB 8.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 1.3/1.4 MB 6.7 MB/s eta 0:00:01
#    ---------------------------------------- 1.4/1.4 MB 6.5 MB/s eta 0:00:00
# Installing collected packages: shapely, pyshp, pyproj, cartopy, geoviews
# Successfully installed cartopy-0.22.0 geoviews-1.10.1 pyproj-3.6.1 pyshp-2.3.1 shapely-2.0.2

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Import API key
from api_keys import geoapify_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID                 City      Lat       Lng  Max Temp  Humidity  \
# 0        0        blackmans bay -43.0167  147.3167      8.62        93
# 1        1            grytviken -54.2811  -36.5092      3.21        92
# 2        2         invercargill -46.4000  168.3500     11.12        85
# 3        3  fale old settlement  -9.3852 -171.2468     28.31        72
# 4        4              siedlce  52.1677   22.2901      4.84        72
#
#    Cloudiness  Wind Speed Country        Date
# 0          84        0.45      AU  1697659804
# 1         100        4.15      GS  1697659806
# 2         100        2.24      NZ  1697659808
# 3         100        3.75      TK  1697659808
# 4          18        3.10      PL  1697659808

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
city_map = city_data_df.hvplot.points("Lng", 
                                      "Lat", 
                                      geo = True,
                                      color = "City",
                                      alpha = 0.6,
                                      size = "Humidity",
                                      tiles = "OSM"
                                     )

# Display the map
city_map
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values

# My Criteria:
# A max temperature lower than 27 degrees but higher than 21
# Cloudiness less than 3
# Wind speed less than 4.5 m/s
# Drop any rows with null values

weather_filtered_df = city_data_df.loc[(city_data_df["Max Temp"] < 27)
                                       & (city_data_df["Max Temp"] > 21) 
                                       & (city_data_df["Cloudiness"] < 3)
                                       & (city_data_df["Wind Speed"] < 4.5)
                                      ]

# Drop any rows with null values
weather_filtered_df.dropna()

# Display sample data
weather_filtered_df
# Out:
#      City_ID            City      Lat       Lng  Max Temp  Humidity  \
# 17        17         lebanon  36.2081  -86.2911     23.58        45
# 21        21   dayr al balah  31.4166   34.3452     23.81        59
# 70        70      brookhaven  31.5791  -90.4407     26.25        24
# 71        71         sesheke -17.4759   24.2968     24.34        25
# 74        74        banswara  23.5500   74.4500     24.60        51
# 223      223    mersa matruh  31.3525   27.2453     23.35        63
# 242      242        marshall  34.3834  -86.3333     22.99        47
# 251      251           kelso  46.1468 -122.9084     23.00        56
# 258      258          najran  17.4924   44.1277     22.36        26
# 283      283          sohagi  24.9833   81.7000     23.56        60
# 286      286        tshabong -26.0500   22.4500     22.40        24
# 292      292      mahasamund  21.1000   82.1000     21.35        79
# 302      302     tamanrasset  22.7850    5.5228     24.95        16
# 310      310       lasalgaon  20.1500   74.2333     23.33        62
# 362      362           raton  36.9034 -104.4391     22.34        18
# 382      382        upington -28.4478   21.2561     26.21        19
# 407      407           bayji  34.9311   43.4870     23.88        35
# 416      416        damietta  31.4165   31.8133     23.79        67
# 420      420         al wajh  26.2455   36.4525     23.97        64
# 427      427      north bend  43.4065 -124.2243     21.07        94
# 449      449       pakpattan  30.3410   73.3866     21.66        44
# 459      459  carolina beach  34.0352  -77.8936     23.37        54
# 475      475          pombas  17.1503  -25.0201     26.88        69
# 492      492       okahandja -21.9833   16.9167     21.26        32
# 496      496         al hazm  16.1641   44.7769     24.51        24
# 512      512         awjilah  29.1081   21.2869     23.98        30
# 517      517      baharampur  24.1000   88.2500     23.82        74
# 534      534          ghanzi -21.5667   21.7833     22.31        24
# 566      566   morehead city  34.7229  -76.7260     22.00        53
# 577      577        karratha -20.7377  116.8463     26.27        45
#
#      Cloudiness  Wind Speed Country        Date
# 17            0        4.12      US  1697659608
# 21            0        3.15      PS  1697659812
# 70            0        2.92      US  1697659827
# 71            0        2.41      ZM  1697659827
# 74            0        0.64      IN  1697659828
# 223           0        2.51      EG  1697659872
# 242           0        0.00      US  1697659878
# 251           0        1.34      US  1697659880
# 258           0        1.67      SA  1697659882
# 283           0        0.24      IN  1697659892
# 286           0        3.60      BW  1697659895
# 292           0        1.28      IN  1697659900
# 302           0        2.06      DZ  1697659903
# 310           0        1.64      IN  1697659905
# 362           0        0.00      US  1697659721
# 382           0        1.54      ZA  1697659921
# 407           2        2.04      IQ  1697659929
# 416           0        4.13      EG  1697659781
# 420           0        1.54      SA  1697659932
# 427           0        3.60      US  1697659933
# 449           0        0.97      PK  1697659938
# 459           0        3.56      US  1697659941
# 475           0        4.24      CV  1697659945
# 492           0        3.46     NaN  1697659949
# 496           0        0.61      YE  1697659950
# 512           1        2.94      LY  1697659953
# 517           0        2.25      IN  1697659954
# 534           0        4.09      BW  1697659958
# 566           0        3.60      US  1697659798
# 577           0        4.38      AU  1697659968

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = weather_filtered_df[["City", "Country", "Lat", "Lng", "Humidity"]].copy()

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df["Hotel Name"] = ""

# Display sample data
hotel_df
# Out:
#                City Country      Lat       Lng  Humidity Hotel Name
# 17          lebanon      US  36.2081  -86.2911        45
# 21    dayr al balah      PS  31.4166   34.3452        59
# 70       brookhaven      US  31.5791  -90.4407        24
# 71          sesheke      ZM -17.4759   24.2968        25
# 74         banswara      IN  23.5500   74.4500        51
# 223    mersa matruh      EG  31.3525   27.2453        63
# 242        marshall      US  34.3834  -86.3333        47
# 251           kelso      US  46.1468 -122.9084        56
# 258          najran      SA  17.4924   44.1277        26
# 283          sohagi      IN  24.9833   81.7000        60
# 286        tshabong      BW -26.0500   22.4500        24
# 292      mahasamund      IN  21.1000   82.1000        79
# 302     tamanrasset      DZ  22.7850    5.5228        16
# 310       lasalgaon      IN  20.1500   74.2333        62
# 362           raton      US  36.9034 -104.4391        18
# 382        upington      ZA -28.4478   21.2561        19
# 407           bayji      IQ  34.9311   43.4870        35
# 416        damietta      EG  31.4165   31.8133        67
# 420         al wajh      SA  26.2455   36.4525        64
# 427      north bend      US  43.4065 -124.2243        94
# 449       pakpattan      PK  30.3410   73.3866        44
# 459  carolina beach      US  34.0352  -77.8936        54
# 475          pombas      CV  17.1503  -25.0201        69
# 492       okahandja     NaN -21.9833   16.9167        32
# 496         al hazm      YE  16.1641   44.7769        24
# 512         awjilah      LY  29.1081   21.2869        30
# 517      baharampur      IN  24.1000   88.2500        74
# 534          ghanzi      BW -21.5667   21.7833        24
# 566   morehead city      US  34.7229  -76.7260        53
# 577        karratha      AU -20.7377  116.8463        45

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000 
params = {"categories": "accommodation.hotel",
          "apiKey":geoapify_key
         }

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    longitude = row["Lng"]
    latitude = row["Lat"]
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude},{latitude}"

    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params = params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# lebanon - nearest hotel: Ramada
# dayr al balah - nearest hotel: البيت
# brookhaven - nearest hotel: The Inn aon Whitworth
# sesheke - nearest hotel: Sisheke Lodge
# banswara - nearest hotel: No hotel found
# mersa matruh - nearest hotel: صقور
# marshall - nearest hotel: Wyndham Garden Lake-Guntersville
# kelso - nearest hotel: Best Western Aladdin Inn
# najran - nearest hotel: No hotel found
# sohagi - nearest hotel: No hotel found
# tshabong - nearest hotel: No hotel found
# mahasamund - nearest hotel: No hotel found
# tamanrasset - nearest hotel: فندق الأمان
# lasalgaon - nearest hotel: No hotel found
# raton - nearest hotel: Travelodge
# upington - nearest hotel: Die Eiland Holiday Ressort
# bayji - nearest hotel: No hotel found
# damietta - nearest hotel: No hotel found
# al wajh - nearest hotel: فندق رالين 2
# north bend - nearest hotel: The Mill Casino Hotel
# pakpattan - nearest hotel: No hotel found
# carolina beach - nearest hotel: Carolina Beach Inn
# pombas - nearest hotel: Aldeia Jerome
# okahandja - nearest hotel: Okahandja Country Hotel
# al hazm - nearest hotel: No hotel found
# awjilah - nearest hotel: No hotel found
# baharampur - nearest hotel: HOTEL THE FAME
# ghanzi - nearest hotel: Ghanzi farmhouse
# morehead city - nearest hotel: Bask Hotel Big Rock Landing, Trademark Collection by Wyndham
# karratha - nearest hotel: Karratha International Hotel
#                City Country      Lat       Lng  Humidity  \
# 17          lebanon      US  36.2081  -86.2911        45
# 21    dayr al balah      PS  31.4166   34.3452        59
# 70       brookhaven      US  31.5791  -90.4407        24
# 71          sesheke      ZM -17.4759   24.2968        25
# 74         banswara      IN  23.5500   74.4500        51
# 223    mersa matruh      EG  31.3525   27.2453        63
# 242        marshall      US  34.3834  -86.3333        47
# 251           kelso      US  46.1468 -122.9084        56
# 258          najran      SA  17.4924   44.1277        26
# 283          sohagi      IN  24.9833   81.7000        60
# 286        tshabong      BW -26.0500   22.4500        24
# 292      mahasamund      IN  21.1000   82.1000        79
# 302     tamanrasset      DZ  22.7850    5.5228        16
# 310       lasalgaon      IN  20.1500   74.2333        62
# 362           raton      US  36.9034 -104.4391        18
# 382        upington      ZA -28.4478   21.2561        19
# 407           bayji      IQ  34.9311   43.4870        35
# 416        damietta      EG  31.4165   31.8133        67
# 420         al wajh      SA  26.2455   36.4525        64
# 427      north bend      US  43.4065 -124.2243        94
# 449       pakpattan      PK  30.3410   73.3866        44
# 459  carolina beach      US  34.0352  -77.8936        54
# 475          pombas      CV  17.1503  -25.0201        69
# 492       okahandja     NaN -21.9833   16.9167        32
# 496         al hazm      YE  16.1641   44.7769        24
# 512         awjilah      LY  29.1081   21.2869        30
# 517      baharampur      IN  24.1000   88.2500        74
# 534          ghanzi      BW -21.5667   21.7833        24
# 566   morehead city      US  34.7229  -76.7260        53
# 577        karratha      AU -20.7377  116.8463        45
#
#                                             Hotel Name
# 17                                              Ramada
# 21                                               البيت
# 70                               The Inn aon Whitworth
# 71                                       Sisheke Lodge
# 74                                      No hotel found
# 223                                               صقور
# 242                   Wyndham Garden Lake-Guntersville
# 251                           Best Western Aladdin Inn
# 258                                     No hotel found
# 283                                     No hotel found
# 286                                     No hotel found
# 292                                     No hotel found
# 302                                        فندق الأمان
# 310                                     No hotel found
# 362                                         Travelodge
# 382                         Die Eiland Holiday Ressort
# 407                                     No hotel found
# 416                                     No hotel found
# 420                                       فندق رالين 2
# 427                              The Mill Casino Hotel
# 449                                     No hotel found
# 459                                 Carolina Beach Inn
# 475                                      Aldeia Jerome
# 492                            Okahandja Country Hotel
# 496                                     No hotel found
# 512                                     No hotel found
# 517                                     HOTEL THE FAME
# 534                                   Ghanzi farmhouse
# 566  Bask Hotel Big Rock Landing, Trademark Collect...
# 577                       Karratha International Hotel

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
hotel_map = hotel_df.hvplot.points("Lng", 
                                   "Lat", 
                                   geo = True,
                                   color = "City",
                                   alpha = 0.8,
                                   size = "Humidity",
                                   tiles = "OSM",
                                   hover_cols = ["Hotel Name", "Country"]
                                  )


# Display the map
hotel_map
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Hotel Name,Country)
